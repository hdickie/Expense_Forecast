# %%
library(ggplot2)
library(reshape2)

# %%
data <- read.table('/home/hdickie/sandbox/results.csv',sep=',',stringsAsFactors=FALSE,header=TRUE)

#data$Credit.1 <- 20000 - data$Credit.1 #flipping these y axis so the plot isnt as sparse
#data$Credit.1.Grace.Period.Balance <- 20000 - data$Credit.1.Grace.Period.Balance

melted.data <- melt(data)

title_text=paste("Expense Forecast:",min(data$Date),'->',max(data$Date),collapse=' ')
subtitle_text=paste("Generated",Sys.time(),collapse=' ')

png('/home/hdickie/sandbox/results.png',width=1800,height=1000)

ggplot(melted.data,aes(x=Date,y=value,group=variable,color=variable)) + geom_line(size=2) + theme(plot.subtitle = element_text(hjust = 0.5,size=20), legend.title=element_text(size=14,face="bold"),axis.title=element_text(size=18,face="bold"), plot.title = element_text(hjust = 0.5,size=30),axis.text.y = element_text(size=18),axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1,size=18),legend.text=element_text(size=18)) + labs(title = title_text, subtitle = subtitle_text) 

dev.off()
# Out:
# Using Date, Memo as id variables
# png
#   2

# %%
data
# Out:
#    Date       Checking Savings Credit.1 Credit.1.Grace.Period.Balance Loan.A
# 1  2022-06-06  298.48  50      2434.88  1832.54                       4746.180
# 2  2022-06-07  298.48  50      2434.88  1832.54                       4746.180
# 3  2022-06-08  298.48  50      2434.88  1862.54                       4746.180
# 4  2022-06-09  298.48  50      2434.88  1892.54                       4746.180
# 5  2022-06-10  298.48  50      2434.88  1922.54                       4746.180
# 6  2022-06-11  298.48  50      2434.88  1952.54                       4746.180
# 7  2022-06-12  298.48  50      2434.88  2082.54                       4746.180
# 8  2022-06-13  298.48  50      2434.88  2112.54                       4746.180
# 9  2022-06-14  298.48  50      2434.88  2142.54                       4746.180
# 10 2022-06-15  298.48  50      2434.88  2172.54                       4746.180
# 11 2022-06-16  298.48  50      2434.88  2272.54                       4746.180
# ...

# %%
data
# Out:
#    Date       Checking Savings Credit.1 Credit.1.Grace.Period.Balance Loan.A
# 1  2022-06-06  298.48  50      2434.88  1832.54                       4746.180
# 2  2022-06-07  258.48  50      4275.59    30.00                       4746.180
# 3  2022-06-08  258.48  50      4275.59    60.00                       4746.180
# 4  2022-06-09  258.48  50      4275.59    90.00                       4746.180
# 5  2022-06-10  258.48  50      4275.59   120.00                       4746.180
# 6  2022-06-11  258.48  50      4275.59   150.00                       4746.180
# 7  2022-06-12  258.48  50      4275.59   280.00                       4746.180
# 8  2022-06-13  258.48  50      4275.59   310.00                       4746.180
# 9  2022-06-14  258.48  50      4275.59   340.00                       4746.180
# 10 2022-06-15  258.48  50      4275.59   370.00                       4746.180
# 11 2022-06-16  258.48  50      4275.59   470.00                       4746.180
# ...
